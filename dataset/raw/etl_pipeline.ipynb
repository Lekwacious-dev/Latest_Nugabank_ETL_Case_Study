# %%
# import the necessary Libraries
from pyspark.sql import SparkSession
from pyspark.sql import DataFrameWriter
from pyspark.sql.functions import monotonically_increasing_id
import os
import psycopg2

# %%
# set java home
os.environ['JAVA_HOME'] = 'C:\java'

# %%
# INITIALISE MY SPARK SESSION
spark = SparkSession.builder \
        .appName("Nuga Bank ETL") \
        .master("local[*]") \
        .config(
            "spark.jars", 
            r"C:\Users\USER\Desktop\Data_Engineering\pyspark\Latest_NugaBank_ETL_Case_Study\postgresql-42.7.8.jar") \
        .getOrCreate()
        
print(spark.version)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 # INITIALISE MY SPARK SESSION
# ----> 2 spark = SparkSession.builder \
#       3         .appName("Nuga Bank ETL") \
#       4         .master("local[*]") \
#       5         .config(
#       6             "spark.jars",
#       7             r"C:\Users\USER\Desktop\Data_Engineering\pyspark\Latest_NugaBank_ETL_Case_Study\postgresql-42.7.8.jar") \
#       8         .getOrCreate()
#      10 print(spark.version)
#
# File c:\Users\USER\anaconda3\envs\nugabankenv\lib\site-packages\pyspark\sql\session.py:477, in SparkSession.Builder.getOrCreate(self)
#     475     sparkConf.set(key, value)
#     476 # This SparkContext may be an existing one.
# --> 477 sc = SparkContext.getOrCreate(sparkConf)
#     478 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     479 # by all sessions.
# ...

# %%
# Extract this historical data into spark dataframe
df = spark.read.csv(r'dataset/raw/ziko_logistics_data.csv', header=True, inferSchema=True)

# %%
df.show(5)

# %%
df.printSchema()
